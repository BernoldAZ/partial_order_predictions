# %% [markdown]
# # Test data_pipeline_suffix

# %%
from data_pipeline_suffix import build_suffix_dataloaders 

log_path = "baselines/SuffixTransformerNetwork/Logs/Sepsis.xes.gz"

(train_loader, val_loader, test_loader, act_vocab, end_tok, max_suf) = build_suffix_dataloaders(log_path)

batch = next(iter(train_loader))
print(f"\nSample batch – nodes: {batch.x.shape}, "
      f"edges: {batch.edge_index.shape[1]}, "
      f"suffix targets: {batch.y.shape}")
print(f"END_TOKEN index: {end_tok}  |  max_suffix_len: {max_suf}")
print(f"Activity vocab: {list(act_vocab.items())[:5]} …")
# Out:
# Loading event log …
# parsing log, completed traces ::   0%|          | 0/1050 [00:00<?, ?it/s]
# window_size (p98 of full log): 41
# Filtering long cases …
#   Dropping 10 cases with length > 41
#   Dropping 6 cases with length > 41
# Vocabulary size (train+val): 16
# END_TOKEN index: 17  |  max_suffix_len: 41
# Train graphs: 100%|█████████████████████████████████████████| 551/551 [00:01<00:00, 492.11it/s]
# Val graphs  : 100%|█████████████████████████████████████████| 138/138 [00:00<00:00, 592.94it/s]
# Test graphs : 100%|█████████████████████████████████████████| 345/345 [00:00<00:00, 539.37it/s]
# Cases (after filter) – train: 551  val: 138  test: 345
# Graphs – train: 7367  val: 1782  test: 4837
#
# Sample batch – nodes: torch.Size([347, 16]), edges: 424, suffix targets: torch.Size([32, 41])
# END_TOKEN index: 17  |  max_suffix_len: 41
# Activity vocab: [('Admission IC', 0), ('Admission NC', 1), ('CRP', 2), ('ER Registration', 3), ('ER Sepsis Triage', 4)] …

# %% [markdown]
# # Run and evaluate POG

# %%
from run_suffix import run 

log_path = "baselines/SuffixTransformerNetwork/Logs/Sepsis.xes.gz"
log_name = "SEPSIS"
results_dir = "pog_results"
run(log_path, log_name, results_dir)
# Out:
# ============================================================
# Log : SEPSIS
# Device : cuda
# ============================================================
# Loading event log …
# parsing log, completed traces ::   0%|          | 0/1050 [00:00<?, ?it/s]
# window_size (p98 of full log): 41
# Filtering long cases …
#   Dropping 10 cases with length > 41
#   Dropping 6 cases with length > 41
# Cases (after filter) – train: 551  val: 138  test: 345
# Vocabulary size (train+val): 16
# END_TOKEN index: 17  |  max_suffix_len: 41
# Train graphs: 100%|█████████████████████████████████████████| 551/551 [00:01<00:00, 495.15it/s]
# Val graphs  : 100%|█████████████████████████████████████████| 138/138 [00:00<00:00, 669.79it/s]
# Test graphs : 100%|█████████████████████████████████████████| 345/345 [00:00<00:00, 409.77it/s]
# Graphs – train: 7367  val: 1782  test: 4837
#
# Model parameters: 172,946
# Vocab size: 18  |  max_suffix_len: 41
# Epoch   1  train_loss=1.4792  val_loss=1.2687  val_acc=0.3478  val_dls=0.1262
# Epoch   2  train_loss=1.1528  val_loss=1.1992  val_acc=0.3505  val_dls=0.1304
# Epoch   3  train_loss=1.0944  val_loss=1.1667  val_acc=0.3314  val_dls=0.1757
# Epoch   4  train_loss=1.0553  val_loss=1.1518  val_acc=0.3390  val_dls=0.2704
# Epoch   5  train_loss=1.0225  val_loss=1.1359  val_acc=0.3571  val_dls=0.2594
# Epoch   6  train_loss=0.9903  val_loss=1.1111  val_acc=0.3061  val_dls=0.3457
# Epoch   7  train_loss=0.9607  val_loss=1.1015  val_acc=0.3140  val_dls=0.3897
# Epoch   8  train_loss=0.9298  val_loss=1.1128  val_acc=0.3129  val_dls=0.4306
# Epoch   9  train_loss=0.9041  val_loss=1.1235  val_acc=0.3184  val_dls=0.4118
# Epoch  10  train_loss=0.8788  val_loss=1.1205  val_acc=0.2999  val_dls=0.4361
# Epoch  11  train_loss=0.8522  val_loss=1.1368  val_acc=0.3249  val_dls=0.4307
# Epoch  12  train_loss=0.8370  val_loss=1.1569  val_acc=0.3372  val_dls=0.3975
# Epoch  13  train_loss=0.8130  val_loss=1.1572  val_acc=0.2865  val_dls=0.4385
# Epoch  14  train_loss=0.7949  val_loss=1.1758  val_acc=0.2991  val_dls=0.4421
# Epoch  15  train_loss=0.7747  val_loss=1.1846  val_acc=0.3172  val_dls=0.4349
# Epoch  16  train_loss=0.7612  val_loss=1.2021  val_acc=0.3261  val_dls=0.4252
# Epoch  17  train_loss=0.7439  val_loss=1.2178  val_acc=0.2942  val_dls=0.4422
# Epoch  18  train_loss=0.7312  val_loss=1.2408  val_acc=0.2961  val_dls=0.4299
# Epoch  19  train_loss=0.7149  val_loss=1.2316  val_acc=0.2888  val_dls=0.4473
# Epoch  20  train_loss=0.7012  val_loss=1.2479  val_acc=0.2989  val_dls=0.4506
# Epoch  21  train_loss=0.6904  val_loss=1.2485  val_acc=0.2962  val_dls=0.4549
# Epoch  22  train_loss=0.6842  val_loss=1.2644  val_acc=0.3068  val_dls=0.4160
# Epoch  23  train_loss=0.6690  val_loss=1.2824  val_acc=0.3003  val_dls=0.4525
# Epoch  24  train_loss=0.6619  val_loss=1.2961  val_acc=0.2999  val_dls=0.4499
# Epoch  25  train_loss=0.6559  val_loss=1.2968  val_acc=0.2624  val_dls=0.4403
# Epoch  26  train_loss=0.6486  val_loss=1.2968  val_acc=0.2856  val_dls=0.4461
# Epoch  27  train_loss=0.6384  val_loss=1.3158  val_acc=0.3152  val_dls=0.4379
# Epoch  28  train_loss=0.6329  val_loss=1.3253  val_acc=0.3137  val_dls=0.4453
# Epoch  29  train_loss=0.6249  val_loss=1.3094  val_acc=0.2977  val_dls=0.4332
# Epoch  30  train_loss=0.6182  val_loss=1.3300  val_acc=0.3000  val_dls=0.4420
# Epoch  31  train_loss=0.6106  val_loss=1.3576  val_acc=0.3202  val_dls=0.4430
# Early stopping at epoch 31.
#
# ────────────────────────────────────────────────────────────
# Test activity accuracy : 0.2963
# Test mean DLS          : 0.4691
# Training time          : 50.9s
# Testing time           : 1.3s
# Results saved → pog_results/results_suffix_gnn.csv
# {'activity_accuracy': 0.2963297309844987, 'mean_dls': 0.4691392406639194}

# %% [markdown]
# # Run and evalutate POG-time

# %%
from run_suffix_time import run 

log_path = "baselines/SuffixTransformerNetwork/Logs/Sepsis.xes.gz"
log_name = "SEPSIS"
results_dir = "pog_results"
run(log_path, log_name, results_dir)
# Out:
# ============================================================
# Log    : SEPSIS
# Device : cuda
# ============================================================
# Loading event log …
# parsing log, completed traces ::   0%|          | 0/1050 [00:00<?, ?it/s]
# window_size (p98 of full log): 41
# Filtering long cases …
#   Dropping 10 cases with length > 41
#   Dropping 6 cases with length > 41
# Cases (after filter) – train: 551  val: 138  test: 345
# Vocabulary size (train+val): 16
# END_TOKEN index: 17  |  max_suffix_len: 41
# Train graphs: 100%|█████████████████████████████████████████| 551/551 [00:01<00:00, 484.91it/s]
# Val graphs  : 100%|█████████████████████████████████████████| 138/138 [00:00<00:00, 673.67it/s]
# Test graphs : 100%|█████████████████████████████████████████| 345/345 [00:00<00:00, 610.40it/s]
# Graphs – train: 7367  val: 1782  test: 4837
# Time norms  — mean TTNE: 2118.2 min  mean RRT: 32574.5 min
# Parameters : 173,204
# Vocab size : 18  |  max_suffix_len: 41
# Epoch   1  train=3.4276  val_loss=1.2949  acc=0.3024  dls=0.1204  ttne=733.71m  rrt=8161.81m
# Epoch   2  train=3.0630  val_loss=1.2027  acc=0.3164  dls=0.2169  ttne=728.20m  rrt=8162.25m
# Epoch   3  train=2.9819  val_loss=1.1633  acc=0.3602  dls=0.1737  ttne=717.29m  rrt=8175.28m
# Epoch   4  train=2.9307  val_loss=1.1480  acc=0.2732  dls=0.3421  ttne=711.54m  rrt=7935.03m
# Epoch   5  train=2.8934  val_loss=1.1399  acc=0.2913  dls=0.2796  ttne=708.39m  rrt=8083.82m
# Epoch   6  train=2.8607  val_loss=1.1235  acc=0.3423  dls=0.2241  ttne=711.18m  rrt=8491.23m
# Epoch   7  train=2.8227  val_loss=1.1256  acc=0.3699  dls=0.3140  ttne=708.45m  rrt=8033.42m
# Epoch   8  train=2.7905  val_loss=1.1111  acc=0.3095  dls=0.3750  ttne=703.79m  rrt=8099.08m
# Epoch   9  train=2.7630  val_loss=1.1329  acc=0.3113  dls=0.4279  ttne=705.25m  rrt=8455.36m
# Epoch  10  train=2.7349  val_loss=1.1303  acc=0.2977  dls=0.4277  ttne=701.58m  rrt=8002.46m
# Epoch  11  train=2.7209  val_loss=1.1553  acc=0.3185  dls=0.4150  ttne=700.72m  rrt=8472.62m
# Epoch  12  train=2.6909  val_loss=1.1583  acc=0.3082  dls=0.4399  ttne=698.95m  rrt=8266.19m
# Epoch  13  train=2.6790  val_loss=1.1546  acc=0.3211  dls=0.4216  ttne=702.31m  rrt=8595.97m
# Epoch  14  train=2.6485  val_loss=1.1822  acc=0.2912  dls=0.4531  ttne=698.17m  rrt=8187.94m
# Epoch  15  train=2.6272  val_loss=1.2038  acc=0.3063  dls=0.4417  ttne=698.55m  rrt=8770.30m
# Epoch  16  train=2.6130  val_loss=1.2180  acc=0.3219  dls=0.4480  ttne=700.95m  rrt=8693.52m
# Epoch  17  train=2.5982  val_loss=1.2179  acc=0.3148  dls=0.4337  ttne=699.86m  rrt=8445.82m
# Epoch  18  train=2.5831  val_loss=1.2348  acc=0.3163  dls=0.4452  ttne=700.07m  rrt=9212.60m
# Epoch  19  train=2.5673  val_loss=1.2601  acc=0.3050  dls=0.4098  ttne=699.21m  rrt=8518.22m
# Epoch  20  train=2.5553  val_loss=1.2630  acc=0.2323  dls=0.4248  ttne=698.24m  rrt=8204.89m
# Epoch  21  train=2.5498  val_loss=1.2798  acc=0.3196  dls=0.4472  ttne=700.20m  rrt=8314.96m
# Epoch  22  train=2.5310  val_loss=1.3038  acc=0.2863  dls=0.4555  ttne=697.19m  rrt=8558.57m
# Epoch  23  train=2.5256  val_loss=1.3075  acc=0.2891  dls=0.4583  ttne=698.46m  rrt=8379.11m
# Epoch  24  train=2.5140  val_loss=1.3268  acc=0.3107  dls=0.4358  ttne=698.82m  rrt=9107.90m
# Epoch  25  train=2.5018  val_loss=1.3292  acc=0.2756  dls=0.4367  ttne=697.53m  rrt=9345.98m
# Epoch  26  train=2.4908  val_loss=1.3444  acc=0.3152  dls=0.4410  ttne=696.96m  rrt=8605.47m
# Epoch  27  train=2.4856  val_loss=1.3308  acc=0.2957  dls=0.4578  ttne=703.63m  rrt=8329.20m
# Epoch  28  train=2.4762  val_loss=1.3511  acc=0.2908  dls=0.4474  ttne=698.88m  rrt=8509.57m
# Epoch  29  train=2.4724  val_loss=1.3555  acc=0.3106  dls=0.4339  ttne=700.83m  rrt=8379.06m
# Epoch  30  train=2.4643  val_loss=1.3743  acc=0.2899  dls=0.4491  ttne=699.41m  rrt=8523.29m
# Epoch  31  train=2.4582  val_loss=1.3761  acc=0.3021  dls=0.4528  ttne=696.84m  rrt=8484.97m
# Epoch  32  train=2.4521  val_loss=1.4120  acc=0.3251  dls=0.4064  ttne=699.73m  rrt=9399.55m
# Epoch  33  train=2.4452  val_loss=1.4037  acc=0.3034  dls=0.4481  ttne=698.22m  rrt=8791.58m
# Early stopping at epoch 33.
#
# ────────────────────────────────────────────────────────────
# Test activity accuracy : 0.2897
# Test mean DLS          : 0.4612
# Test MAE TTNE          : 5097.14 min
# Test MAE RRT           : 72405.56 min
# Training time          : 58.3s
# Testing time           : 1.4s
# Results saved → pog_results/results_suffix_gnn_time.csv
# {'activity_accuracy': 0.2897010652291661,
#  'mean_dls': 0.4612000603503601,
#  'mae_ttne_minutes': 5097.135972548843,
#  'mae_rrt_minutes': 72405.56281097098}

# %% [markdown]
# ## Important notes
#
#  All experimental conditions: split, filtering, vocabulary, and evaluation metric, match the baselines.

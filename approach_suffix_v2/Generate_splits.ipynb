# %% [markdown]
# # Generate Data splits

# %% [markdown]
# ## Graph gat preprocessing (delta time in edges)

# %%
from create_graph_data import run_all_logs

folder = "Logs"
output_file = "split_summary_gat.csv"
run_all_logs(folder, output_file)
# Out:
# Processing 9 logs with 9 workers ...
# Auto-detected features:
#   cat_casefts  : []
#   num_casefts  : []
#   cat_eventfts : ['InfectionSuspected', 'org:group', 'DiagnosticBlood', 'DisfuncOrg', 'SIRSCritTachypnea', 'Hypotensie', 'SIRSCritHeartRate', 'Infusion', 'DiagnosticArtAstrup', 'DiagnosticIC', 'DiagnosticSputum', 'DiagnosticLiquor', 'DiagnosticOther', 'SIRSCriteria2OrMore', 'DiagnosticXthorax', 'SIRSCritTemperature', 'DiagnosticUrinaryCulture', 'SIRSCritLeucos', 'Oligurie', 'DiagnosticLacticAcid', 'lifecycle:transition', 'Diagnose', 'Hypoxie', 'DiagnosticUrinarySediment', 'DiagnosticECG']
#   num_eventfts : ['Age', 'Leucocytes', 'CRP', 'LacticAcid']
# Auto-derived window_size (98.5th percentile): 41
# Auto-derived max_days (maximum case duration): 422.32
# Generating Dataframes...
# 100%|██████████████████████████████████████████| 26/26 [00:00<00:00, 489.88it/s]
# 100%|██████████████████████████████████████████| 26/26 [00:00<00:00, 624.70it/s]
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
#   cat_eventfts : ['org:resource', 'lifecycle:transition']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 17
# Cases – train: 599  val: 150  test: 285
# Pairs – train: 8025  val: 1904  test: 4057
# Generating Graph Datasets...
# Computing train graph dataset ...
# Auto-derived max_days (maximum case duration): 89.51
# Generating Dataframes...
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 348.53it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 33.01it/s]
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
#   cat_eventfts : ['org:resource', 'lifecycle:transition']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 8
# Cases – train: 2635  val: 659  test: 1667
# Pairs – train: 15852  val: 3999  test: 10235
# Generating Graph Datasets...
# Computing train graph dataset ...
# Auto-detected features:
#   cat_casefts  : ['case:Includes_subCases', 'case:Responsible_actor', 'case:endDate', 'case:caseStatus', 'case:parts', 'case:caseProcedure', 'case:last_phase', 'case:case_type', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:termName', 'case:landRegisterID']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['monitoringResource', 'org:resource', 'activityNameNL', 'question', 'dateFinished', 'action_code', 'activityNameEN', 'planned', 'lifecycle:transition', 'dueDate', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 101
# Auto-derived max_days (maximum case duration): 1326.00
# Generating Dataframes...
# Auto-detected features:
#   cat_casefts  : ['case:Responsible_actor', 'case:endDate', 'case:caseStatus', 'case:parts', 'case:last_phase', 'case:case_type', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:termName', 'case:caseProcedure', 'case:landRegisterID', 'case:Includes_subCases', 'case:endDatePlanned']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 79
#   0%|                                                    | 0/25 [00:00<?, ?it/s]
# Auto-derived max_days (maximum case duration): 927.00
# Generating Dataframes...
#  52%|█████████████████████▊                    | 13/25 [00:00<00:00, 129.21it/s]
# Auto-derived max_days (maximum case duration): 91.41
# Generating Dataframes...
# Auto-detected features:
#   cat_casefts  : ['case:endDate', 'case:caseStatus', 'case:last_phase', 'case:case_type', 'case:Responsible_actor', 'case:parts', 'case:termName', 'case:endDatePlanned', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:landRegisterID', 'case:caseProcedure', 'case:Includes_subCases']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
#   0%|                                                    | 0/26 [00:00<?, ?it/s]
# Auto-derived window_size (98.5th percentile): 82
# 100%|███████████████████████████████████████████| 25/25 [00:00<00:00, 63.21it/s]
#  46%|███████████████████▍                      | 12/26 [00:00<00:00, 118.01it/s]
# Auto-derived max_days (maximum case duration): 1486.00
# Generating Dataframes...
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 53.28it/s]
#   0%|                                                    | 0/26 [00:00<?, ?it/s]
# Auto-detected features:
#   cat_casefts  : ['case:endDate', 'case:caseStatus', 'case:last_phase', 'case:case_type', 'case:Responsible_actor', 'case:landRegisterID', 'case:parts', 'case:termName', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:caseProcedure', 'case:Includes_subCases', 'case:endDatePlanned']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 92
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 170.92it/s]
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# Auto-derived max_days (maximum case duration): 1344.00
# Generating Dataframes...
#  54%|███████████████████████▏                   | 14/26 [00:00<00:00, 55.65it/s]
# Auto-detected features:
#   cat_casefts  : ['case:Includes_subCases', 'case:Responsible_actor', 'case:caseStatus', 'case:last_phase', 'case:case_type', 'case:termName', 'case:startDate', 'case:requestComplete', 'case:endDate', 'case:parts', 'case:caseProcedure', 'case:IDofConceptCase', 'case:endDatePlanned', 'case:landRegisterID']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 81
#  85%|████████████████████████████████████▍      | 22/26 [00:00<00:00, 52.44it/s]
# Auto-derived max_days (maximum case duration): 1512.00
# Generating Dataframes...
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 51.95it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  6.07it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 45.86it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 40.95it/s]
#  42%|█████████████████▊                        | 11/26 [00:00<00:00, 107.55it/s]
# Cases – train: 7718  val: 1930  test: 3439
# Pairs – train: 36026  val: 7917  test: 16906
# Generating Graph Datasets...
# Computing train graph dataset ...
# Auto-detected features:
#  84%|████████████████████████████████████       | 21/25 [00:03<00:00,  6.96it/s]
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
#   cat_eventfts : ['org:resource', 'lifecycle:transition']
#   num_eventfts : []
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  8.23it/s]
# Auto-derived window_size (98.5th percentile): 65
# 100%|███████████████████████████████████████████| 26/26 [00:02<00:00,  9.73it/s]
# Auto-derived max_days (maximum case duration): 137.18
# Generating Dataframes...
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 54.28it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 10.62it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:04<00:00,  5.23it/s]
# Cases – train: 617  val: 155  test: 266
# Pairs – train: 26627  val: 7988  test: 11335
# Generating Graph Datasets...
# Computing train graph dataset ...
# Cases – train: 480  val: 121  test: 218
# Pairs – train: 24702  val: 6958  test: 11243
# Generating Graph Datasets...
# Computing train graph dataset ...
# 100%|███████████████████████████████████████████| 26/26 [00:07<00:00,  3.66it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:06<00:00,  3.76it/s]
# Cases – train: 693  val: 174  test: 271
# Pairs – train: 34299  val: 9386  test: 13494
# Generating Graph Datasets...
# Computing train graph dataset ...
# Cases – train: 709  val: 178  test: 295
# Pairs – train: 28587  val: 8698  test: 13412
# Generating Graph Datasets...
# Computing train graph dataset ...
# Cases – train: 5439  val: 1360  test: 2714
# Pairs – train: 88975  val: 15700  test: 53068
# Generating Graph Datasets...
# Computing train graph dataset ...
# Computing validation graph dataset ...
# Cases – train: 849  val: 213  test: 327
# Pairs – train: 34457  val: 9571  test: 13825
# Generating Graph Datasets...
# Computing train graph dataset ...
# Computing test graph dataset ...
# Tensors saved to 'results_per_log/Sepsis/'
# tss_index = 4  (= 0 num_casefts + 4 num_eventfts)
# Use this value for the tss_index parameter in TRAIN_EVAL_*.py scripts.
# Concurrent-trace test samples: 2905 / 2915
#   Sepsis  train=599 (8025 pairs)  val=150 (1904 pairs)  test=285 (4057 pairs)  conc=2905
# Computing validation graph dataset ...
# Computing test graph dataset ...
# Computing validation graph dataset ...
# Tensors saved to 'results_per_log/BPI_Challenge_2012_O/'
# tss_index = 0  (= 0 num_casefts + 0 num_eventfts)
# Use this value for the tss_index parameter in TRAIN_EVAL_*.py scripts.
# Concurrent-trace test samples: 5896 / 7029
#   BPI_Challenge_2012_O  train=2635 (15852 pairs)  val=659 (3999 pairs)  test=1667 (10235 pairs)  conc=5896
# Computing validation graph dataset ...
# Computing validation graph dataset ...
# Computing validation graph dataset ...
# Computing test graph dataset ...
# Computing test graph dataset ...
# Computing test graph dataset ...
# Computing validation graph dataset ...
# Computing validation graph dataset ...
# Computing test graph dataset ...
# Computing test graph dataset ...
# Computing test graph dataset ...
# Tensors saved to 'results_per_log/BPIC15_2/'
# tss_index = 1  (= 1 num_casefts + 0 num_eventfts)
# Use this value for the tss_index parameter in TRAIN_EVAL_*.py scripts.
# Concurrent-trace test samples: 9211 / 9212
#   BPIC15_2  train=480 (24702 pairs)  val=121 (6958 pairs)  test=218 (11243 pairs)  conc=9211
# Tensors saved to 'results_per_log/BPIC15_4/'
# tss_index = 1  (= 1 num_casefts + 0 num_eventfts)
# Use this value for the tss_index parameter in TRAIN_EVAL_*.py scripts.
# Concurrent-trace test samples: 8938 / 8939
#   BPIC15_4  train=617 (26627 pairs)  val=155 (7988 pairs)  test=266 (11335 pairs)  conc=8938
# Tensors saved to 'results_per_log/BPI_Challenge_2012_A/'
# tss_index = 0  (= 0 num_casefts + 0 num_eventfts)
# Use this value for the tss_index parameter in TRAIN_EVAL_*.py scripts.
# Concurrent-trace test samples: 10377 / 13171
#   BPI_Challenge_2012_A  train=7718 (36026 pairs)  val=1930 (7917 pairs)  test=3439 (16906 pairs)  conc=10377
# Tensors saved to 'results_per_log/BPIC15_1/'
# tss_index = 1  (= 1 num_casefts + 0 num_eventfts)
# Use this value for the tss_index parameter in TRAIN_EVAL_*.py scripts.
# Concurrent-trace test samples: 11915 / 11915
#   BPIC15_1  train=709 (28587 pairs)  val=178 (8698 pairs)  test=295 (13412 pairs)  conc=11915
# Tensors saved to 'results_per_log/BPIC15_5/'
# tss_index = 1  (= 1 num_casefts + 0 num_eventfts)
# Use this value for the tss_index parameter in TRAIN_EVAL_*.py scripts.
# Concurrent-trace test samples: 11757 / 11757
#   BPIC15_5  train=693 (34299 pairs)  val=174 (9386 pairs)  test=271 (13494 pairs)  conc=11757
# Tensors saved to 'results_per_log/BPIC15_3/'
# tss_index = 1  (= 1 num_casefts + 0 num_eventfts)
# Use this value for the tss_index parameter in TRAIN_EVAL_*.py scripts.
# Concurrent-trace test samples: 13056 / 13056
#   BPIC15_3  train=849 (34457 pairs)  val=213 (9571 pairs)  test=327 (13825 pairs)  conc=13056
# Computing validation graph dataset ...
# Computing test graph dataset ...
# Tensors saved to 'results_per_log/BPI_Challenge_2012_W/'
# tss_index = 0  (= 0 num_casefts + 0 num_eventfts)
# Use this value for the tss_index parameter in TRAIN_EVAL_*.py scripts.
# Concurrent-trace test samples: 36984 / 39688
#   BPI_Challenge_2012_W  train=5439 (88975 pairs)  val=1360 (15700 pairs)  test=2714 (53068 pairs)  conc=36984
#
# Summary written to 'split_summary_gat.csv'.

# %% [markdown]
# ## Graph sequential gat preprocessing (delta time in edges)

# %%
from create_seq_graph_data import run_all_logs

folder = "Logs"
output_file = "split_summary_gat.csv"
run_all_logs(folder, output_file)
# Out:
# Processing 9 logs with 9 workers ...
# Auto-detected features:
#   cat_casefts  : []
#   num_casefts  : []
#   cat_eventfts : ['InfectionSuspected', 'org:group', 'DiagnosticBlood', 'DisfuncOrg', 'SIRSCritTachypnea', 'Hypotensie', 'SIRSCritHeartRate', 'Infusion', 'DiagnosticArtAstrup', 'DiagnosticIC', 'DiagnosticSputum', 'DiagnosticLiquor', 'DiagnosticOther', 'SIRSCriteria2OrMore', 'DiagnosticXthorax', 'SIRSCritTemperature', 'DiagnosticUrinaryCulture', 'SIRSCritLeucos', 'Oligurie', 'DiagnosticLacticAcid', 'lifecycle:transition', 'Diagnose', 'Hypoxie', 'DiagnosticUrinarySediment', 'DiagnosticECG']
#   num_eventfts : ['Age', 'Leucocytes', 'CRP', 'LacticAcid']
# Auto-derived window_size (98.5th percentile): 41
# Auto-derived max_days (maximum case duration): 422.32
# Generating Dataframes...
#   0%|                                                    | 0/26 [00:00<?, ?it/s]
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
#   cat_eventfts : ['org:resource', 'lifecycle:transition']
#   num_eventfts : []
# 100%|██████████████████████████████████████████| 26/26 [00:00<00:00, 473.78it/s]
# Auto-derived window_size (98.5th percentile): 17
#   0%|                                                    | 0/26 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 26/26 [00:00<00:00, 552.17it/s]
# Auto-derived max_days (maximum case duration): 89.51
# Generating Dataframes...
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# Cases – train: 599  val: 150  test: 285
# Pairs – train: 8025  val: 1904  test: 4057
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 293.93it/s]
# Generating Seq-Graph Datasets...
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# Computing train seq-graph dataset ...
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 32.05it/s]
# Cases – train: 2635  val: 659  test: 1667
# Pairs – train: 15852  val: 3999  test: 10235
# Generating Seq-Graph Datasets...
# Computing train seq-graph dataset ...
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
#   cat_eventfts : ['org:resource', 'lifecycle:transition']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 8
# Auto-detected features:
#   cat_casefts  : ['case:Includes_subCases', 'case:Responsible_actor', 'case:endDate', 'case:caseStatus', 'case:parts', 'case:caseProcedure', 'case:last_phase', 'case:case_type', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:termName', 'case:landRegisterID']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['monitoringResource', 'org:resource', 'activityNameNL', 'question', 'dateFinished', 'action_code', 'activityNameEN', 'planned', 'lifecycle:transition', 'dueDate', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 101
# Auto-derived max_days (maximum case duration): 1326.00
# Generating Dataframes...
# Auto-detected features:
#   cat_casefts  : ['case:Responsible_actor', 'case:endDate', 'case:caseStatus', 'case:parts', 'case:last_phase', 'case:case_type', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:termName', 'case:caseProcedure', 'case:landRegisterID', 'case:Includes_subCases', 'case:endDatePlanned']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 79
# Auto-derived max_days (maximum case duration): 927.00
# Generating Dataframes...
#  52%|█████████████████████▊                    | 13/25 [00:00<00:00, 126.01it/s]
# Auto-derived max_days (maximum case duration): 91.41
# Generating Dataframes...
#   0%|                                                    | 0/26 [00:00<?, ?it/s]
# Auto-detected features:
#   cat_casefts  : ['case:endDate', 'case:caseStatus', 'case:last_phase', 'case:case_type', 'case:Responsible_actor', 'case:parts', 'case:termName', 'case:endDatePlanned', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:landRegisterID', 'case:caseProcedure', 'case:Includes_subCases']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 82
# 100%|███████████████████████████████████████████| 25/25 [00:00<00:00, 58.14it/s]
#   0%|                                                    | 0/25 [00:00<?, ?it/s]
# Auto-derived max_days (maximum case duration): 1486.00
# Generating Dataframes...
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 52.84it/s]
#   0%|                                                    | 0/26 [00:00<?, ?it/s]
# Auto-detected features:
#   cat_casefts  : ['case:endDate', 'case:caseStatus', 'case:last_phase', 'case:case_type', 'case:Responsible_actor', 'case:landRegisterID', 'case:parts', 'case:termName', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:caseProcedure', 'case:Includes_subCases', 'case:endDatePlanned']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 92
# Auto-detected features:
#   cat_casefts  : ['case:Includes_subCases', 'case:Responsible_actor', 'case:caseStatus', 'case:last_phase', 'case:case_type', 'case:termName', 'case:startDate', 'case:requestComplete', 'case:endDate', 'case:parts', 'case:caseProcedure', 'case:IDofConceptCase', 'case:endDatePlanned', 'case:landRegisterID']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 81
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 166.48it/s]
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# Auto-derived max_days (maximum case duration): 1344.00
# Generating Dataframes...
#   4%|█▋                                          | 1/26 [00:00<00:05,  4.89it/s]
# Auto-derived max_days (maximum case duration): 1512.00
# Generating Dataframes...
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 51.48it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  5.96it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 64.42it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 61.92it/s]
#  62%|█████████████████████████▊                | 16/26 [00:00<00:00, 117.84it/s]
# Cases – train: 7718  val: 1930  test: 3439
# Pairs – train: 36026  val: 7917  test: 16906
# Generating Seq-Graph Datasets...
# Computing train seq-graph dataset ...
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  8.32it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:02<00:00,  9.63it/s]
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
#   cat_eventfts : ['org:resource', 'lifecycle:transition']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 65
# Auto-derived max_days (maximum case duration): 137.18
# Generating Dataframes...
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 54.01it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 10.37it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:05<00:00,  5.13it/s]
# Cases – train: 617  val: 155  test: 266
# Pairs – train: 26627  val: 7988  test: 11335
# Generating Seq-Graph Datasets...
# Computing train seq-graph dataset ...
# Cases – train: 480  val: 121  test: 218
# Pairs – train: 24702  val: 6958  test: 11243
# Generating Seq-Graph Datasets...
# Computing train seq-graph dataset ...
# 100%|███████████████████████████████████████████| 26/26 [00:07<00:00,  3.65it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:07<00:00,  3.61it/s]
# Cases – train: 693  val: 174  test: 271
# Pairs – train: 34299  val: 9386  test: 13494
# Generating Seq-Graph Datasets...
# Computing train seq-graph dataset ...
# Cases – train: 709  val: 178  test: 295
# Pairs – train: 28587  val: 8698  test: 13412
# Generating Seq-Graph Datasets...
# Computing train seq-graph dataset ...
# Computing validation seq-graph dataset ...
# Cases – train: 849  val: 213  test: 327
# Pairs – train: 34457  val: 9571  test: 13825
# Generating Seq-Graph Datasets...
# Computing train seq-graph dataset ...
# Cases – train: 5439  val: 1360  test: 2714
# Pairs – train: 88975  val: 15700  test: 53068
# Generating Seq-Graph Datasets...
# Computing train seq-graph dataset ...
# Computing test seq-graph dataset ...
# Tensors saved to 'results_per_log/Sepsis/'
# tss_index = 4
#   Sepsis  train=599 (8025 pairs)  val=150 (1904 pairs)  test=285 (4057 pairs)
# Computing validation seq-graph dataset ...
# Computing test seq-graph dataset ...
# Computing validation seq-graph dataset ...
# Computing validation seq-graph dataset ...
# Tensors saved to 'results_per_log/BPI_Challenge_2012_O/'
# tss_index = 0
#   BPI_Challenge_2012_O  train=2635 (15852 pairs)  val=659 (3999 pairs)  test=1667 (10235 pairs)
# Computing validation seq-graph dataset ...
# Computing validation seq-graph dataset ...
# Computing test seq-graph dataset ...
# Computing test seq-graph dataset ...
# Computing validation seq-graph dataset ...
# Computing test seq-graph dataset ...
# Computing validation seq-graph dataset ...
# Computing test seq-graph dataset ...
# Computing test seq-graph dataset ...
# Computing test seq-graph dataset ...
# Tensors saved to 'results_per_log/BPIC15_2/'
# tss_index = 1
#   BPIC15_2  train=480 (24702 pairs)  val=121 (6958 pairs)  test=218 (11243 pairs)
# Tensors saved to 'results_per_log/BPIC15_4/'
# tss_index = 1
#   BPIC15_4  train=617 (26627 pairs)  val=155 (7988 pairs)  test=266 (11335 pairs)
# Tensors saved to 'results_per_log/BPI_Challenge_2012_A/'
# tss_index = 0
#   BPI_Challenge_2012_A  train=7718 (36026 pairs)  val=1930 (7917 pairs)  test=3439 (16906 pairs)
# Tensors saved to 'results_per_log/BPIC15_1/'
# tss_index = 1
#   BPIC15_1  train=709 (28587 pairs)  val=178 (8698 pairs)  test=295 (13412 pairs)
# Tensors saved to 'results_per_log/BPIC15_5/'
# tss_index = 1
#   BPIC15_5  train=693 (34299 pairs)  val=174 (9386 pairs)  test=271 (13494 pairs)
# Tensors saved to 'results_per_log/BPIC15_3/'
# tss_index = 1
#   BPIC15_3  train=849 (34457 pairs)  val=213 (9571 pairs)  test=327 (13825 pairs)
# Computing validation seq-graph dataset ...
# Computing test seq-graph dataset ...
# Tensors saved to 'results_per_log/BPI_Challenge_2012_W/'
# tss_index = 0
#   BPI_Challenge_2012_W  train=5439 (88975 pairs)  val=1360 (15700 pairs)  test=2714 (53068 pairs)
#
# Summary written to 'split_summary_gat.csv'.

# %% [markdown]
# ## Graph sequential flipped gat preprocessing (delta time in edges)

# %%
from create_seq_graph_data_flip import run_all_logs

folder = "Logs"
output_file = "split_summary_gat_flipped.csv"
run_all_logs(folder, output_file)
# Out:
# Processing 9 logs with 9 workers ...
# Auto-detected features:
#   cat_casefts  : []
#   num_casefts  : []
#   cat_eventfts : ['InfectionSuspected', 'org:group', 'DiagnosticBlood', 'DisfuncOrg', 'SIRSCritTachypnea', 'Hypotensie', 'SIRSCritHeartRate', 'Infusion', 'DiagnosticArtAstrup', 'DiagnosticIC', 'DiagnosticSputum', 'DiagnosticLiquor', 'DiagnosticOther', 'SIRSCriteria2OrMore', 'DiagnosticXthorax', 'SIRSCritTemperature', 'DiagnosticUrinaryCulture', 'SIRSCritLeucos', 'Oligurie', 'DiagnosticLacticAcid', 'lifecycle:transition', 'Diagnose', 'Hypoxie', 'DiagnosticUrinarySediment', 'DiagnosticECG']
#   num_eventfts : ['Age', 'Leucocytes', 'CRP', 'LacticAcid']
# Auto-derived window_size (98.5th percentile): 41
# Auto-derived max_days (maximum case duration): 422.32
# Generating Dataframes (flipped test) ...
# 100%|██████████████████████████████████████████| 26/26 [00:00<00:00, 485.67it/s]
#   0%|                                                    | 0/26 [00:00<?, ?it/s]
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
#   cat_eventfts : ['org:resource', 'lifecycle:transition']
#   num_eventfts : []
# 100%|██████████████████████████████████████████| 26/26 [00:00<00:00, 564.78it/s]
# Auto-derived window_size (98.5th percentile): 17
# Auto-derived max_days (maximum case duration): 89.51
# Generating Dataframes (flipped test) ...
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 329.59it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 23.09it/s]
# Cases – test: 285  pairs: 4057
# Generating Seq-Graph Dataset (flipped) ...
# Computing test seq-graph dataset (flipped) ...
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
#   cat_eventfts : ['org:resource', 'lifecycle:transition']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 8
# Auto-detected features:
#   cat_casefts  : ['case:Includes_subCases', 'case:Responsible_actor', 'case:endDate', 'case:caseStatus', 'case:parts', 'case:caseProcedure', 'case:last_phase', 'case:case_type', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:termName', 'case:landRegisterID']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['monitoringResource', 'org:resource', 'activityNameNL', 'question', 'dateFinished', 'action_code', 'activityNameEN', 'planned', 'lifecycle:transition', 'dueDate', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 101
# Auto-derived max_days (maximum case duration): 1326.00
# Generating Dataframes (flipped test) ...
# Auto-detected features:
#   cat_casefts  : ['case:Responsible_actor', 'case:endDate', 'case:caseStatus', 'case:parts', 'case:last_phase', 'case:case_type', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:termName', 'case:caseProcedure', 'case:landRegisterID', 'case:Includes_subCases', 'case:endDatePlanned']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 79
#   0%|                                                    | 0/25 [00:00<?, ?it/s]
# Auto-derived max_days (maximum case duration): 927.00
# Generating Dataframes (flipped test) ...
#  56%|███████████████████████▌                  | 14/25 [00:00<00:00, 134.20it/s]
# Auto-derived max_days (maximum case duration): 91.41
# Generating Dataframes (flipped test) ...
# Cases – test: 1667  pairs: 10235
# Generating Seq-Graph Dataset (flipped) ...
# Computing test seq-graph dataset (flipped) ...
# Auto-detected features:
#   cat_casefts  : ['case:endDate', 'case:caseStatus', 'case:last_phase', 'case:case_type', 'case:Responsible_actor', 'case:parts', 'case:termName', 'case:endDatePlanned', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:landRegisterID', 'case:caseProcedure', 'case:Includes_subCases']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 82
# 100%|███████████████████████████████████████████| 25/25 [00:00<00:00, 62.39it/s]
#  46%|███████████████████▍                      | 12/26 [00:00<00:00, 116.88it/s]
# Auto-derived max_days (maximum case duration): 1486.00
# Generating Dataframes (flipped test) ...
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 53.35it/s]
#   0%|                                                    | 0/26 [00:00<?, ?it/s]
# Auto-detected features:
#   cat_casefts  : ['case:endDate', 'case:caseStatus', 'case:last_phase', 'case:case_type', 'case:Responsible_actor', 'case:landRegisterID', 'case:parts', 'case:termName', 'case:startDate', 'case:requestComplete', 'case:IDofConceptCase', 'case:caseProcedure', 'case:Includes_subCases', 'case:endDatePlanned']
#   num_casefts  : ['case:SUMleges']
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 92
#  62%|█████████████████████████▊                | 16/26 [00:00<00:00, 148.68it/s]
# Auto-detected features:
#   cat_casefts  : ['case:Includes_subCases', 'case:Responsible_actor', 'case:caseStatus', 'case:last_phase', 'case:case_type', 'case:termName', 'case:startDate', 'case:requestComplete', 'case:endDate', 'case:parts', 'case:caseProcedure', 'case:IDofConceptCase', 'case:endDatePlanned', 'case:landRegisterID']
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 158.87it/s]
#   num_casefts  : ['case:SUMleges']
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
#   cat_eventfts : ['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN', 'planned', 'monitoringResource', 'org:resource', 'activityNameNL', 'lifecycle:transition', 'dateStop']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 81
# Auto-derived max_days (maximum case duration): 1344.00
# Generating Dataframes (flipped test) ...
#   4%|█▋                                          | 1/26 [00:00<00:05,  4.61it/s]
# Auto-derived max_days (maximum case duration): 1512.00
# Generating Dataframes (flipped test) ...
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 50.38it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 43.69it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:00<00:00, 44.86it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:01<00:00,  4.16it/s]
#  54%|██████████████████████▌                   | 14/26 [00:00<00:00, 139.89it/s]
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
#   cat_eventfts : ['org:resource', 'lifecycle:transition']
#   num_eventfts : []
# Auto-derived window_size (98.5th percentile): 65
# Auto-derived max_days (maximum case duration): 137.18
# Generating Dataframes (flipped test) ...
# 100%|███████████████████████████████████████████| 25/25 [00:04<00:00,  5.79it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:03<00:00,  6.72it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 51.00it/s]
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# Cases – test: 3439  pairs: 16906
# Generating Seq-Graph Dataset (flipped) ...
# Computing test seq-graph dataset (flipped) ...
# Saved to 'results_per_log/Sepsis/test_seqgraphdataset_flip.pt'
# tss_index = 4
#   Sepsis  test=285 (4057 pairs)
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  7.33it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:07<00:00,  3.59it/s]
# Cases – test: 266  pairs: 11335
# Generating Seq-Graph Dataset (flipped) ...
# Computing test seq-graph dataset (flipped) ...
# Cases – test: 218  pairs: 11243
# Generating Seq-Graph Dataset (flipped) ...
# Computing test seq-graph dataset (flipped) ...
# 100%|███████████████████████████████████████████| 26/26 [00:10<00:00,  2.48it/s]
# 100%|███████████████████████████████████████████| 26/26 [00:10<00:00,  2.47it/s]
# Cases – test: 271  pairs: 13494
# Generating Seq-Graph Dataset (flipped) ...
# Computing test seq-graph dataset (flipped) ...
# Saved to 'results_per_log/BPI_Challenge_2012_O/test_seqgraphdataset_flip.pt'
# tss_index = 0
#   BPI_Challenge_2012_O  test=1667 (10235 pairs)
# Cases – test: 295  pairs: 13412
# Generating Seq-Graph Dataset (flipped) ...
# Computing test seq-graph dataset (flipped) ...
# Cases – test: 327  pairs: 13825
# Generating Seq-Graph Dataset (flipped) ...
# Computing test seq-graph dataset (flipped) ...
# Cases – test: 2714  pairs: 53068
# Generating Seq-Graph Dataset (flipped) ...
# Computing test seq-graph dataset (flipped) ...
# Saved to 'results_per_log/BPIC15_4/test_seqgraphdataset_flip.pt'
# tss_index = 1
#   BPIC15_4  test=266 (11335 pairs)
# Saved to 'results_per_log/BPIC15_2/test_seqgraphdataset_flip.pt'
# tss_index = 1
#   BPIC15_2  test=218 (11243 pairs)
# Saved to 'results_per_log/BPI_Challenge_2012_A/test_seqgraphdataset_flip.pt'
# tss_index = 0
#   BPI_Challenge_2012_A  test=3439 (16906 pairs)
# Saved to 'results_per_log/BPIC15_5/test_seqgraphdataset_flip.pt'
# tss_index = 1
#   BPIC15_5  test=271 (13494 pairs)
# Saved to 'results_per_log/BPIC15_1/test_seqgraphdataset_flip.pt'
# tss_index = 1
#   BPIC15_1  test=295 (13412 pairs)
# Saved to 'results_per_log/BPIC15_3/test_seqgraphdataset_flip.pt'
# tss_index = 1
#   BPIC15_3  test=327 (13825 pairs)
# Saved to 'results_per_log/BPI_Challenge_2012_W/test_seqgraphdataset_flip.pt'
# tss_index = 0
#   BPI_Challenge_2012_W  test=2714 (53068 pairs)
#
# Summary written to 'split_summary_gat_flipped.csv'.

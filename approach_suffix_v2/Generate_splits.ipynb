# %% [markdown]
# # Generate Data splits

# %% [markdown]
# ## Graph gat preprocessing (delta time in edges)

# %%
from create_graph_data import run_all_logs

folder = "Logs"
output_file = "split_summary_gat.csv"
run_all_logs(folder, output_file)
# Out:
# Processing 9 logs with 9 workers ...
# Auto-detected features:
#   cat_casefts  : []
#   num_casefts  : []
#   cat_eventfts : ['InfectionSuspected', 'org:group', 'DiagnosticBlood', 'DisfuncOrg', 'SIRSCritTachypnea', 'Hypotensie', 'SIRSCritHeartRate', 'Infusion', 'DiagnosticArtAstrup', 'DiagnosticIC', 'DiagnosticSputum', 'DiagnosticLiquor', 'DiagnosticOther', 'SIRSCriteria2OrMore', 'DiagnosticXthorax', 'SIRSCritTemperature', 'DiagnosticUrinaryCulture', 'SIRSCritLeucos', 'Oligurie', 'DiagnosticLacticAcid', 'lifecycle:transition', 'Diagnose', 'Hypoxie', 'DiagnosticUrinarySediment', 'DiagnosticECG']
#   num_eventfts : ['Age', 'Leucocytes', 'CRP', 'LacticAcid']
# Auto-derived window_size (98.5th percentile): 41
# Auto-derived max_days (maximum case duration): 422.32
# Generating Dataframes...
# ...
# 100%|██████████████████████████████████████████| 26/26 [00:00<00:00, 624.70it/s]
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
# ...

# %% [markdown]
# Graph sequential gat preprocessing (delta time in edges)

# %%
from create_seq_graph_data import run_all_logs

folder = "Logs"
output_file = "split_summary_gat.csv"
run_all_logs(folder, output_file)
# Out:
# Processing 9 logs with 9 workers ...
# Auto-detected features:
#   cat_casefts  : []
#   num_casefts  : []
#   cat_eventfts : ['InfectionSuspected', 'org:group', 'DiagnosticBlood', 'DisfuncOrg', 'SIRSCritTachypnea', 'Hypotensie', 'SIRSCritHeartRate', 'Infusion', 'DiagnosticArtAstrup', 'DiagnosticIC', 'DiagnosticSputum', 'DiagnosticLiquor', 'DiagnosticOther', 'SIRSCriteria2OrMore', 'DiagnosticXthorax', 'SIRSCritTemperature', 'DiagnosticUrinaryCulture', 'SIRSCritLeucos', 'Oligurie', 'DiagnosticLacticAcid', 'lifecycle:transition', 'Diagnose', 'Hypoxie', 'DiagnosticUrinarySediment', 'DiagnosticECG']
#   num_eventfts : ['Age', 'Leucocytes', 'CRP', 'LacticAcid']
# Auto-derived window_size (98.5th percentile): 41
# Auto-derived max_days (maximum case duration): 422.32
# Generating Dataframes...
#   0%|                                                    | 0/26 [00:00<?, ?it/s]
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
# ...

# %% [markdown]
# ## Graph sage preprocessing (delta time in nodes)

# %%
from create_sage_data import run_all_logs

folder = "Logs"
output_file = "split_summary_sage.csv"
run_all_logs(folder, output_file,n_workers=16)
# Out:
# Processing 9 logs with 9 workers ...
# Auto-detected features:
#   cat_casefts  : []
#   num_casefts  : []
#   cat_eventfts : ['InfectionSuspected', 'org:group', 'DiagnosticBlood', 'DisfuncOrg', 'SIRSCritTachypnea', 'Hypotensie', 'SIRSCritHeartRate', 'Infusion', 'DiagnosticArtAstrup', 'DiagnosticIC', 'DiagnosticSputum', 'DiagnosticLiquor', 'DiagnosticOther', 'SIRSCriteria2OrMore', 'DiagnosticXthorax', 'SIRSCritTemperature', 'DiagnosticUrinaryCulture', 'SIRSCritLeucos', 'Oligurie', 'DiagnosticLacticAcid', 'lifecycle:transition', 'Diagnose', 'Hypoxie', 'DiagnosticUrinarySediment', 'DiagnosticECG']
#   num_eventfts : ['Age', 'Leucocytes', 'CRP', 'LacticAcid']
# Auto-derived window_size (98.5th percentile): 41
# Auto-derived max_days (maximum case duration): 422.32
# Generating Dataframes...
# ...
#   0%|                                                    | 0/26 [00:00<?, ?it/s]
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
# ...

# %% [markdown]
# ## Sequential preprocessing

# %%
from create_seq_data import run_all_logs

folder = "Logs"
output_file = "split_summary_seq.csv"
run_all_logs(folder, output_file,n_workers=16)
# Out:
# Processing 9 logs with 9 workers ...
# Auto-detected features:
#   cat_casefts  : []
#   num_casefts  : []
#   cat_eventfts : ['InfectionSuspected', 'org:group', 'DiagnosticBlood', 'DisfuncOrg', 'SIRSCritTachypnea', 'Hypotensie', 'SIRSCritHeartRate', 'Infusion', 'DiagnosticArtAstrup', 'DiagnosticIC', 'DiagnosticSputum', 'DiagnosticLiquor', 'DiagnosticOther', 'SIRSCriteria2OrMore', 'DiagnosticXthorax', 'SIRSCritTemperature', 'DiagnosticUrinaryCulture', 'SIRSCritLeucos', 'Oligurie', 'DiagnosticLacticAcid', 'lifecycle:transition', 'Diagnose', 'Hypoxie', 'DiagnosticUrinarySediment', 'DiagnosticECG']
#   num_eventfts : ['Age', 'Leucocytes', 'CRP', 'LacticAcid']
# Auto-derived window_size (98.5th percentile): 41
# Auto-derived max_days: 422.32
# Generating Dataframes...
# ...
# 100%|██████████████████████████████████████████| 26/26 [00:00<00:00, 633.64it/s]
# Auto-detected features:
#   cat_casefts  : ['case:REG_DATE', 'case:AMOUNT_REQ']
#   num_casefts  : []
# ...

# %% [markdown]
# ## Scaffold preprocessing

# %%
from create_scaffold_data import run_all_logs

run_all_logs('results_per_log', 'scaffold_summary.csv', n_workers=16)
# Out:
# Processing 17 logs with 16 workers ...
#   ERROR  BPI Challenge 2018: [Errno 2] No such file or directory: 'results_per_log/BPI Challenge 2018/BPI Challenge 2018_train_means_dict.pkl'
#   ERROR  Hospital_log: [Errno 2] No such file or directory: 'results_per_log/Hospital_log/Hospital_log_train_means_dict.pkl'
# Building train scaffold dataset (8025 samples) ...
# Building train scaffold dataset (9796 samples) ...
# Building train scaffold dataset (15852 samples) ...
# Building train scaffold dataset (21727 samples) ...
# Building train scaffold dataset (24702 samples) ...
# Building train scaffold dataset (26627 samples) ...
# Building train scaffold dataset (28587 samples) ...
# Building train scaffold dataset (33223 samples) ...
# Building train scaffold dataset (32129 samples) ...
# Building train scaffold dataset (36026 samples) ...
# Building train scaffold dataset (34457 samples) ...
# Building train scaffold dataset (34299 samples) ...
# ...

# %% [markdown]
# ## Multiple activities per step

# %%
from create_multilabel_data import run_all_logs

folder = "../baselines/SuffixTransformerNetwork/Logs"
output_file = "split_summary.csv"
run_all_logs(folder, output_file)
# Out:
# Processing 15 logs with 15 workers ...
# Auto-derived window_size: 41
# Generating Dataframes...
#   0%|                                                                                | 0/26 [00:00<?, ?it/s]
# Auto-derived window_size: 14
# ...
#   0%|                                                                                | 0/26 [00:00<?, ?it/s]
# Auto-derived window_size: 17
# 100%|██████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 496.55it/s]
# Generating Dataframes...
# ...
#   0%|                                                                                | 0/17 [00:00<?, ?it/s]
# Generating Dataframes...
# Auto-derived window_size: 10
# Cases – train: 599  val: 150  test: 285
# Pairs – train: 8025  val: 1904  test: 4057
# Generating Multilabel Graph Datasets...
# Computing T_max from training set ...
# ...
# 100%|███████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 21.98it/s]
# ...
